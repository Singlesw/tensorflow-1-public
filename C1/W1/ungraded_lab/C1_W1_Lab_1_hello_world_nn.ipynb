# %% [markdown]
# <a href="https://github.com/Singlesw/tensorflow-1-public/tree/main/C1/W1/ungraded_lab/C1_W1_Lab_1_hello_world_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ungraded Lab: The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# Like every first app, you should start with something super simple that shows the overall scaffolding for how your code works. In the case of creating neural networks, one simple case is where it learns the relationship between two numbers. So, for example, if you were writing code for a function like this, you already know the 'rules':
#
# >Як і кожну першу програму, вам слід почати з чогось надзвичайно простого, що покаже загальну схему роботи вашого коду. У випадку зі створенням нейронних мереж, одним з простих випадків є те, що вони вивчають співвідношення між двома числами. Тож, наприклад, якщо ви писали код для такої функції, ви вже знаєте "правила":
#
#
# ```
# def hw_function(x):
#     y = (2 * x) - 1
#     return y
# ```
#
# So how would you train a neural network to do the equivalent task? By using data! By feeding it with a set of x's and y's, it should be able to figure out the relationship between them.
#
# This is obviously a very different paradigm from what you might be used to. So let's step through it piece by piece.
#
# >Тож як би ви навчили нейронну мережу виконувати еквівалентну задачу? За допомогою даних! Якщо ви дасте їй набір значень x та y, вона зможе з'ясувати зв'язок між ними.
# >
# >Очевидно, що це зовсім інша парадигма, ніж та, до якої ви звикли. Тож давайте пройдемося по ній крок за кроком.

# %% [markdown]
# ## Imports
#
# Let's start with the imports. Here, you are importing [TensorFlow](https://www.tensorflow.org/) and calling it `tf` for convention and ease of use.
#
# You then import a library called [`numpy`](https://numpy.org) which helps to represent data as arrays easily and to optimize numerical operations.
#
# The framework you will use to build a neural network as a sequence of layers is called [`keras`](https://keras.io/) so you will import that too.
#
# >## Імпорт
# >
# >Почнемо з імпорту. Тут ви імпортуєте [TensorFlow](https://www.tensorflow.org/) і називаєте його `tf` для зручності використання.
# >
# >Потім ви імпортуєте бібліотеку під назвою [`numpy`](https://numpy.org), яка допомагає легко представляти дані у вигляді масивів та оптимізувати числові операції.
# >
# >Фреймворк, який ви будете використовувати для побудови нейронної мережі у вигляді послідовності шарів, називається [`keras`](https://keras.io/), тому ви також імпортуєте його.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)

# %% [markdown]
# ## Define and Compile the Neural Network
#
# Next, you will create the simplest possible neural network. It has 1 layer with 1 neuron, and the input shape to it is just 1 value. You will build this model using Keras' [Sequential](https://keras.io/api/models/sequential/) class which allows you to define the network as a sequence of [layers](https://keras.io/api/layers/). You can use a single [Dense](https://keras.io/api/layers/core_layers/dense/) layer to build this simple network as shown below.
#
# >## Визначення та компіляція нейронної мережі
# >
# >Далі ви створите найпростішу нейронну мережу. Вона має 1 шар з 1 нейроном, і вхідною формою для неї є лише 1 значення. Ви побудуєте цю модель за допомогою класу Sequential Keras, який дозволяє визначити мережу як послідовність шарів. Ви можете використовувати один шар Dense для побудови цієї простої мережі, як показано нижче.

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# Now, you will compile the neural network. When you do so, you have to specify 2 functions: a [loss](https://keras.io/api/losses/) and an [optimizer](https://keras.io/api/optimizers/).
#
# If you've seen lots of math for machine learning, here's where it's usually used. But in this case, it's nicely encapsulated in functions and classes for you. But what happens here? Let's explain...
#
# You know that in the function declared at the start of this notebook, the relationship between the numbers is `y=2x-1`. When the computer is trying to 'learn' that, it makes a guess... maybe `y=10x+10`. The `loss` function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the `optimizer` function to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with something like `y=5x+5`, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower).
#
# It will repeat this for the number of _epochs_ which you will see shortly. But first, here's how you will tell it to use [mean squared error](https://keras.io/api/losses/regression_losses/#meansquarederror-function) for the loss and [stochastic gradient descent](https://keras.io/api/optimizers/sgd/) for the optimizer. You don't need to understand the math for these yet, but you can see that they work!
#
# Over time, you will learn the different and appropriate loss and optimizer functions for different scenarios.
#
# >Тепер ви маєте скомпілювати нейронну мережу. Для цього вам потрібно вказати 2 функції: [втрата](https://keras.io/api/losses/) та [оптимізатор](https://keras.io/api/optimizers/).
# >
# >Якщо ви бачили багато математики для машинного навчання, то ось де вона зазвичай використовується. Але в цьому випадку, вона красиво інкапсульована у функції та класи для вас. Але що тут відбувається? Давайте пояснимо...
# >
# >Ви знаєте, що у функції, оголошеній на початку цього зошита, залежність між числами має вигляд `y=2x-1`. Коли комп'ютер намагається "вивчити" це, він робить припущення... можливо, `y=10x+10`. Функція `loss` порівнює вгадані відповіді з відомими правильними відповідями і визначає, наскільки добре чи погано вона вгадала.
# >
# >Потім вона використовує функцію `оптимізатора`, щоб зробити ще одне припущення. Виходячи з того, як спрацювала функція втрат, вона намагатиметься мінімізувати втрати. Можливо, на цьому етапі він прийде до чогось на кшталт `y=5x+5`, що, хоч і досить погано, але ближче до правильного результату (тобто втрати менші).
# >
# >Він буде повторювати це протягом певної кількості _епох_, яку ви побачите незабаром. Але спочатку, ось як ви скажете йому використовувати [середню квадратичну похибку](https://keras.io/api/losses/regression_losses/#meansquarederror-function) для втрат і [стохастичний градієнтний спуск](https://keras.io/api/optimizers/sgd/) для оптимізатора. Вам ще не потрібно розуміти математику цих методів, але ви можете побачити, що вони працюють!
# >
# >З часом ви вивчите різні та відповідні функції втрат і оптимізатора для різних типів даних.

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data
#
# Next up, you will feed in some data. In this case, you are taking 6 X's and 6 Y's. You can see that the relationship between these is `y=2x-1`, so where `x = -1`, `y=-3` etc.
#
# The de facto standard way of declaring model inputs and outputs is to use `numpy`, a Python library that provides lots of array type data structures. You can specify these values by building numpy arrays with [`np.array()`](https://numpy.org/doc/stable/reference/generated/numpy.array.html).
#
# >## Надання даних
# >
# >Далі вам потрібно ввести деякі дані. У цьому випадку ви вводите 6 чисел X та 6 чисел Y. Ви можете бачити, що зв'язок між ними має вигляд `y=2x-1`, отже, де `x = -1`, `y=-3` і т.д.
# >
# >Де-факто стандартним способом оголошення входів і виходів моделі є використання `numpy`, бібліотеки Python, яка надає багато структур даних типу масивів. Ви можете вказати ці значення, створивши масиви numpy за допомогою [`np.array()`](https://numpy.org/doc/stable/reference/generated/numpy.array.html).

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network
#
# The process of training the neural network, where it 'learns' the relationship between the x's and y's is in the [`model.fit()`](https://keras.io/api/models/model_training_apis/#fit-method)  call. This is where it will go through the loop we spoke about above: making a guess, measuring how good or bad it is (aka the loss), using the optimizer to make another guess etc. It will do it for the number of `epochs` you specify. When you run this code, you'll see the loss on the right hand side.
#
# ># Навчання нейронної мережі
# >
# >Процес навчання нейронної мережі, де вона "вивчає" зв'язок між x та y, відбувається у виклику [`model.fit()`](https://keras.io/api/models/model_training_apis/#fit-method). Саме тут він буде проходити цикл, про який ми говорили вище: робити здогад, вимірювати, наскільки він правильний чи неправильний (він же втрата), використовувати оптимізатор, щоб зробити ще один здогад, і т.д. Він буде робити це протягом вказаної вами кількості `епох`. Коли ви запустите цей код, ви побачите втрати праворуч.

# %%
# Train the model
model.fit(xs, ys, epochs=500)

# %% [markdown]
# Ok, now you have a model that has been trained to learn the relationship between `x` and `y`. You can use the [`model.predict()`](https://keras.io/api/models/model_training_apis/#predict-method) method to have it figure out the `y` for a previously unknown `x`. So, for example, if `x=10`, what do you think `y` will be? Take a guess before you run this code:
#
# >Гаразд, тепер у вас є модель, яка навчена визначати зв'язок між `x` та `y`. Ви можете скористатися методом [`model.predict()`](https://keras.io/api/models/model_training_apis/#predict-method), щоб вона визначила значення `y` для раніше невідомого значення `x`. Наприклад, якщо `x=10`, як ви думаєте, яким буде `y`? Спробуйте здогадатися, перш ніж запускати цей код:

# %%
# Make a prediction
print(model.predict([10.0]))

# %% [markdown]
# You might have thought `19`, right? But it ended up being a little under. Why do you think that is?
#
# Remember that neural networks deal with probabilities. So given the data that we fed the model with, it calculated that there is a very high probability that the relationship between `x` and `y` is `y=2x-1`, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
#
# As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
#
# >Ви, мабуть, подумали "19", так? Але виявилося трохи менше. Як ви думаєте, чому?
# >
# >Пам'ятайте, що нейронні мережі мають справу з ймовірностями. Отже, враховуючи дані, які ми надали моделі, вона вирахувала, що існує дуже висока ймовірність того, що зв'язок між `x` та `y` буде `y=2x-1`, але маючи лише 6 точок даних, ми не можемо знати це напевно. В результаті, результат для 10 дуже близький до 19, але не обов'язково дорівнює 19.
# >
# >Працюючи з нейронними мережами, ви побачите, що ця закономірність повторюється. Ви майже завжди матимете справу з ймовірностями, а не з упевненістю, і будете трохи кодувати, щоб з'ясувати, який результат базується на ймовірностях, особливо коли мова йде про класифікацію.
