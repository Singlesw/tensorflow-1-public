# %% [markdown]
# <a href="https://colab.research.google.com/github/Singlesw/tensorflow-1-public/blob/main/C1/W1/assignment/C1W1_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Assignment: Housing Prices
#
# In this exercise you'll try to build a neural network that predicts the price of a house according to a simple formula.
#
# Imagine that house pricing is as easy as:
#
# A house has a base cost of 50k, and every additional bedroom adds a cost of 50k. This will make a 1 bedroom house cost 100k, a 2 bedroom house cost 150k etc.
#
# How would you create a neural network that learns this relationship so that it would predict a 7 bedroom house as costing close to 400k etc.
#
# Hint: Your network might work better if you scale the house price down. You don't have to give the answer 400...it might be better to create something that predicts the number 4, and then your answer is in the 'hundreds of thousands' etc.
#
# ># Завдання 1-го тижня: Ціни на житло
# >
# >У цій вправі ви спробуєте побудувати нейронну мережу, яка прогнозує ціну на житло за простою формулою.
# >
# >Уявіть, що ціноутворення на житло дуже просте:
# >
# >Будинок має базову вартість 50 тисяч, а кожна додаткова спальня додає ще 50 тисяч. Таким чином, будинок з 1 спальнею коштуватиме 100 тисяч, з 2 спальнями - 150 тисяч і т.д.
# >
# >Як би ви створили нейронну мережу, яка б вивчила цю залежність, щоб передбачити, що будинок з 7 спальнями коштуватиме близько 400 тисяч і т.д.?
# >
# >Підказка: Ваша мережа може працювати краще, якщо ви зменшите ціну будинку. Вам не обов'язково давати відповідь 400... можливо, краще створити щось, що передбачатиме число 4, і тоді ваша відповідь буде в межах "сотень тисяч" і т.д.

# %%
import tensorflow as tf
import numpy as np

# %%
# GRADED FUNCTION: house_model
def house_model():
    ### START CODE HERE

    # Define input and output tensors with the values for houses with 1 up to 6 bedrooms
    # Hint: Remember to explictly set the dtype as float
    xs = None
    ys = None

    # Define your model (should be a model with 1 dense layer and 1 unit)
    model = None

    # Compile your model
    # Set the optimizer to Stochastic Gradient Descent
    # and use Mean Squared Error as the loss function
    model.compile(optimizer=None, loss=None)

    # Train your model for 1000 epochs by feeding the i/o tensors
    model.fit(None, None, epochs=None)

    ### END CODE HERE
    return model

# %% [markdown]
# Now that you have a function that returns a compiled and trained model when invoked, use it to get the model to predict the price of houses:
#
# >Тепер, коли у вас є функція, яка повертає скомпільовану і навчену модель при виклику, використовуйте її, щоб отримати модель для прогнозування цін на будинки:

# %%
# Get your trained model
model = house_model()

# %% [markdown]
# Now that your model has finished training it is time to test it out! You can do so by running the next cell.
#
# >Тепер, коли ваша модель закінчила навчання, настав час її протестувати! Ви можете зробити це, запустивши наступну комірку.

# %%
new_y = 7.0
prediction = model.predict([new_y])[0]
print(prediction)

# %% [markdown]
# If everything went as expected you should see a prediction value very close to 4. **If not, try adjusting your code before submitting the assignment.** Notice that you can play around with the value of `new_y` to get different predictions. In general you should see that the network was able to learn the linear relationship between `x` and `y`, so if you use a value of 8.0 you should get a prediction close to 4.5 and so on.
#
# >Якщо все пройшло як очікувалося, ви повинні побачити значення прогнозу дуже близьке до 4. **Якщо це не так, спробуйте скоригувати свій код перед відправкою завдання.** Зверніть увагу, що ви можете погратися зі значенням `new_y`, щоб отримати різні прогнози. Загалом, ви повинні побачити, що мережа змогла вивчити лінійну залежність між `x` та `y`, тому, якщо ви використовуєте значення 8.0, ви повинні отримати прогноз близький до 4.5 і так далі.

# %% [markdown]
# **Congratulations on finishing this week's assignment!**
#
# You have successfully coded a neural network that learned the linear relationship between two variables. Nice job!
#
# **Keep it up!**
#
# >**Вітаємо з виконанням завдання цього тижня!
# >
# >Ви успішно створили нейронну мережу, яка навчилася визначати лінійну залежність між двома змінними. Чудова робота!
# >
# >**Так тримати!
